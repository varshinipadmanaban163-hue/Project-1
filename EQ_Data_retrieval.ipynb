# %% [markdown]
# ##Data retrieval

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import pandas as pd
from datetime import datetime

# %%
all_records = []
start_year = datetime.now().year - 5   # last 5 years
end_year = datetime.now().year

url = "https://earthquake.usgs.gov/fdsnws/event/1/query"

# %%
for year in range(start_year, end_year + 1):
    for month in range(1, 13):
        start_date = f"{year}-{month:02d}-01"
        if month == 12:
            end_date = f"{year+1}-01-01"
        else:
            end_date = f"{year}-{month+1:02d}-01"

        params = {
            "format": "geojson",
            "starttime": start_date,
            "endtime": end_date,
            "minmagnitude": 3
        }

        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f" Failed for {start_date}: {response.text[:200]}")
            continue

        try:
            data = response.json()
        except Exception as e:
            print(f" JSON error for {start_date}: {e}")
            continue

        for f in data["features"]:
            p = f["properties"]
            g = f["geometry"]["coordinates"]
            all_records.append({
                "id": f.get("id"),
                "time": pd.to_datetime(p.get("time"), unit="ms"),
                "updated": pd.to_datetime(p.get("updated"), unit="ms"),
                "latitude": g[1] if g else None,
                "longitude": g[0] if g else None,
                "depth_km": g[2] if g else None,
                "mag": p.get("mag"),
                "magType": p.get("magType"),
                "place": p.get("place"),
                "status": p.get("status"),
                "tsunami": p.get("tsunami"),
                "alert": p.get("alert"),
                "felt": p.get("felt"),
                "cdi": p.get("cdi"),
                "mmi": p.get("mmi"),
                "sig": p.get("sig"),
                "net": p.get("net"),
                "code": p.get("code"),
                "ids": p.get("ids"),
                "sources": p.get("sources"),
                "types": p.get("types"),
                "nst": p.get("nst"),
                "dmin": p.get("dmin"),
                "rms": p.get("rms"),
                "gap": p.get("gap"),
                "type": p.get("type")
            })

# %%
all_records
# Out:
# [{'id': 'us6000ddi8',
#   'time': Timestamp('2021-01-31 23:20:49.923000'),
#   'updated': Timestamp('2021-04-16 19:02:44.040000'),
#   'latitude': -31.7493,
#   'longitude': -68.9337,
#   'depth_km': 17.27,
#   'mag': 4.7,
#   'magType': 'mwr',
#   'place': '29 km SW of Villa Basilio Nievas, Argentina',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 12,
#   'cdi': 3.7,
#   'mmi': None,
#   'sig': 344,
#   'net': 'us',
#   'code': '6000ddi8',
#   'ids': ',us6000ddi8,',
#   'sources': ',us,',
#   'types': ',dyfi,moment-tensor,origin,phase-data,',
#   'nst': None,
#   'dmin': 0.294,
#   'rms': 0.82,
#   'gap': 42,
#   'type': 'earthquake'},
#  {'id': 'us6000dev6',
#   'time': Timestamp('2021-01-31 23:08:17.161000'),
#   'updated': Timestamp('2021-04-16 19:03:47.040000'),
#   'latitude': -15.4902,
#   'longitude': -177.2052,
#   'depth_km': 426.71,
#   'mag': 4.1,
#   'magType': 'mb',
#   'place': 'Fiji region',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 259,
#   'net': 'us',
#   'code': '6000dev6',
#   'ids': ',us6000dev6,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.471,
#   'rms': 0.29,
#   'gap': 64,
#   'type': 'earthquake'},
#  {'id': 'us6000dev5',
#   'time': Timestamp('2021-01-31 22:54:19.760000'),
#   'updated': Timestamp('2021-04-16 19:03:47.040000'),
#   'latitude': 19.7529,
#   'longitude': 121.3159,
#   'depth_km': 46.73,
#   'mag': 4.7,
#   'magType': 'mb',
#   'place': '103 km SW of Basco, Philippines',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 340,
#   'net': 'us',
#   'code': '6000dev5',
#   'ids': ',us6000dev5,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 3.057,
#   'rms': 0.69,
#   'gap': 106,
#   'type': 'earthquake'},
#  {'id': 'us6000ddhs',
#   'time': Timestamp('2021-01-31 22:06:00.832000'),
#   'updated': Timestamp('2021-04-16 19:02:43.040000'),
#   'latitude': 28.1524,
#   'longitude': 57.257,
#   'depth_km': 10,
#   'mag': 4.9,
#   'magType': 'mb',
#   'place': '114 km N of M?n?b, Iran',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 369,
#   'net': 'us',
#   'code': '6000ddhs',
#   'ids': ',us6000ddhs,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 3.33,
#   'rms': 0.61,
#   'gap': 71,
#   'type': 'earthquake'},
#  {'id': 'us6000dev4',
#   'time': Timestamp('2021-01-31 21:51:14.016000'),
#   'updated': Timestamp('2021-04-16 19:03:46.040000'),
#   'latitude': 71.3212,
#   'longitude': -3.7578,
#   'depth_km': 10,
#   'mag': 4,
#   'magType': 'mb',
#   'place': '184 km ENE of Olonkinbyen, Svalbard and Jan Mayen',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 246,
#   'net': 'us',
#   'code': '6000dev4',
#   'ids': ',us6000dev4,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 6.023,
#   'rms': 0.5,
#   'gap': 65,
#   'type': 'earthquake'},
#  {'id': 'pr2021031019',
#   'time': Timestamp('2021-01-31 21:34:54.690000'),
#   'updated': Timestamp('2021-04-16 19:02:43.040000'),
#   'latitude': 18.9996,
#   'longitude': -65.4121,
#   'depth_km': 46,
#   'mag': 3.55,
#   'magType': 'md',
#   'place': '76 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 194,
#   'net': 'pr',
#   'code': '2021031019',
#   'ids': ',us6000ddhn,pr2021031019,',
#   'sources': ',us,pr,',
#   'types': ',origin,phase-data,',
#   'nst': 11,
#   'dmin': 0.9132,
#   'rms': 0.31,
#   'gap': 305,
#   'type': 'earthquake'},
#  {'id': 'pr2021031018',
#   'time': Timestamp('2021-01-31 21:26:30.180000'),
#   'updated': Timestamp('2021-01-31 21:52:15.880000'),
#   'latitude': 19.025,
#   'longitude': -65.4221,
#   'depth_km': 30,
#   'mag': 3.27,
#   'magType': 'md',
#   'place': '78 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 165,
#   'net': 'pr',
#   'code': '2021031018',
#   'ids': ',pr2021031018,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 9,
#   'dmin': 0.9368,
#   'rms': 0.37,
#   'gap': 305,
#   'type': 'earthquake'},
#  {'id': 'pr2021031020',
#   'time': Timestamp('2021-01-31 21:14:31.020000'),
#   'updated': Timestamp('2021-04-16 19:02:43.040000'),
#   'latitude': 19.0436,
#   'longitude': -65.359,
#   'depth_km': 28,
#   'mag': 3.48,
#   'magType': 'md',
#   'place': '82 km N of Culebra, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 186,
#   'net': 'pr',
#   'code': '2021031020',
#   'ids': ',us6000ddhc,pr2021031020,',
#   'sources': ',us,pr,',
#   'types': ',origin,phase-data,',
#   'nst': 14,
#   'dmin': 0.9659,
#   'rms': 0.37,
#   'gap': 309,
#   'type': 'earthquake'},
#  {'id': 'us6000dev3',
#   'time': Timestamp('2021-01-31 20:57:55.804000'),
#   'updated': Timestamp('2021-04-16 19:03:46.040000'),
#   'latitude': 5.6376,
#   'longitude': 126.715,
#   'depth_km': 18.68,
#   'mag': 4.3,
#   'magType': 'mb',
#   'place': '99 km SE of Pondaguitan, Philippines',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '6000dev3',
#   'ids': ',us6000dev3,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.816,
#   'rms': 0.49,
#   'gap': 139,
#   'type': 'earthquake'},
#  {'id': 'us6000dev2',
#   'time': Timestamp('2021-01-31 20:54:42.248000'),
#   'updated': Timestamp('2021-04-16 19:03:46.040000'),
#   'latitude': 5.8436,
#   'longitude': 126.5404,
#   'depth_km': 75.53,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': '69 km SE of Pondaguitan, Philippines',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 271,
#   'net': 'us',
#   'code': '6000dev2',
#   'ids': ',us6000dev2,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 5.105,
#   'rms': 0.58,
#   'gap': 196,
#   'type': 'earthquake'},
#  {'id': 'pr2021031017',
#   'time': Timestamp('2021-01-31 20:50:37.780000'),
#   'updated': Timestamp('2021-01-31 21:19:53.840000'),
#   'latitude': 18.998,
#   'longitude': -65.4401,
#   'depth_km': 24,
#   'mag': 3.24,
#   'magType': 'md',
#   'place': '75 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 162,
#   'net': 'pr',
#   'code': '2021031017',
#   'ids': ',pr2021031017,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 11,
#   'dmin': 0.9078,
#   'rms': 0.3,
#   'gap': 304,
#   'type': 'earthquake'},
#  {'id': 'pr2021031016',
#   'time': Timestamp('2021-01-31 20:19:19.140000'),
#   'updated': Timestamp('2021-01-31 21:19:30.820000'),
#   'latitude': 19.0061,
#   'longitude': -65.4341,
#   'depth_km': 37,
#   'mag': 3.21,
#   'magType': 'md',
#   'place': '76 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 159,
#   'net': 'pr',
#   'code': '2021031016',
#   'ids': ',pr2021031016,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 5,
#   'dmin': 0.9165,
#   'rms': 0.34,
#   'gap': 305,
#   'type': 'earthquake'},
#  {'id': 'us6000ddgp',
#   'time': Timestamp('2021-01-31 20:04:24.547000'),
#   'updated': Timestamp('2021-04-16 19:02:42.040000'),
#   'latitude': 24.9512,
#   'longitude': 94.4749,
#   'depth_km': 47.39,
#   'mag': 4.1,
#   'magType': 'mb',
#   'place': '52 km NE of Yairipok, India',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 259,
#   'net': 'us',
#   'code': '6000ddgp',
#   'ids': ',us6000ddgp,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.735,
#   'rms': 1.02,
#   'gap': 90,
#   'type': 'earthquake'},
#  {'id': 'us6000deuy',
#   'time': Timestamp('2021-01-31 19:58:35.348000'),
#   'updated': Timestamp('2021-04-16 19:03:45.040000'),
#   'latitude': 3.9662,
#   'longitude': 126.5332,
#   'depth_km': 36.06,
#   'mag': 4.7,
#   'magType': 'mb',
#   'place': '198 km SE of Sarangani, Philippines',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 340,
#   'net': 'us',
#   'code': '6000deuy',
#   'ids': ',us6000deuy,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 3.28,
#   'rms': 0.69,
#   'gap': 119,
#   'type': 'earthquake'},
#  {'id': 'us6000ddge',
#   'time': Timestamp('2021-01-31 19:05:14.367000'),
#   'updated': Timestamp('2025-12-22 18:49:11.950000'),
#   'latitude': 2.6675,
#   'longitude': -59.5879,
#   'depth_km': 5.21,
#   'mag': 5.5,
#   'magType': 'mww',
#   'place': '82 km SSE of Lethem, Guyana',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': 'yellow',
#   'felt': 38,
#   'cdi': 5.2,
#   'mmi': 7.574,
#   'sig': 670,
#   'net': 'us',
#   'code': '6000ddge',
#   'ids': ',us6000ddge,pt21031000,iscgem619782176,',
#   'sources': ',us,pt,iscgem,',
#   'types': ',dyfi,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#   'nst': None,
#   'dmin': 0.972,
#   'rms': 0.54,
#   'gap': 25,
#   'type': 'earthquake'},
#  {'id': 'us6000ddg9',
#   'time': Timestamp('2021-01-31 18:55:06.264000'),
#   'updated': Timestamp('2021-04-16 19:02:40.040000'),
#   'latitude': 43.6348,
#   'longitude': -105.2416,
#   'depth_km': 0,
#   'mag': 3,
#   'magType': 'ml',
#   'place': '23 km ESE of Wright, Wyoming',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 138,
#   'net': 'us',
#   'code': '6000ddg9',
#   'ids': ',us6000ddg9,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.998,
#   'rms': 0.34,
#   'gap': 124,
#   'type': 'mining explosion'},
#  {'id': 'pr2021031014',
#   'time': Timestamp('2021-01-31 18:51:09.750000'),
#   'updated': Timestamp('2021-04-16 19:02:40.040000'),
#   'latitude': 19.0075,
#   'longitude': -65.4261,
#   'depth_km': 51,
#   'mag': 3.57,
#   'magType': 'md',
#   'place': '76 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 196,
#   'net': 'pr',
#   'code': '2021031014',
#   'ids': ',us6000ddg8,pr2021031014,',
#   'sources': ',us,pr,',
#   'types': ',origin,phase-data,',
#   'nst': 13,
#   'dmin': 0.919,
#   'rms': 0.48,
#   'gap': 305,
#   'type': 'earthquake'},
#  {'id': 'pr2021031012',
#   'time': Timestamp('2021-01-31 18:19:16.480000'),
#   'updated': Timestamp('2021-04-16 19:02:40.040000'),
#   'latitude': 18.979,
#   'longitude': -65.4648,
#   'depth_km': 46,
#   'mag': 3.44,
#   'magType': 'md',
#   'place': '72 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 182,
#   'net': 'pr',
#   'code': '2021031012',
#   'ids': ',us6000ddg1,pr2021031012,',
#   'sources': ',us,pr,',
#   'types': ',origin,phase-data,',
#   'nst': 13,
#   'dmin': 0.8861,
#   'rms': 0.34,
#   'gap': 303,
#   'type': 'earthquake'},
#  {'id': 'pr2021031011',
#   'time': Timestamp('2021-01-31 18:09:43.390000'),
#   'updated': Timestamp('2021-04-16 19:02:40.040000'),
#   'latitude': 19.0581,
#   'longitude': -65.3911,
#   'depth_km': 25,
#   'mag': 3.41,
#   'magType': 'md',
#   'place': '83 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 179,
#   'net': 'pr',
#   'code': '2021031011',
#   'ids': ',us6000ddg3,pr2021031011,',
#   'sources': ',us,pr,',
#   'types': ',origin,phase-data,',
#   'nst': 11,
#   'dmin': 0.9743,
#   'rms': 0.34,
#   'gap': 308,
#   'type': 'earthquake'},
#  {'id': 'pr2021031010',
#   'time': Timestamp('2021-01-31 17:59:08.440000'),
#   'updated': Timestamp('2021-04-16 19:02:39.040000'),
#   'latitude': 19.0903,
#   'longitude': -65.3938,
#   'depth_km': 24,
#   'mag': 3.46,
#   'magType': 'md',
#   'place': '86 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 184,
#   'net': 'pr',
#   'code': '2021031010',
#   'ids': ',us6000ddg0,pr2021031010,',
#   'sources': ',us,pr,',
#   'types': ',origin,phase-data,',
#   'nst': 14,
#   'dmin': 1.0056,
#   'rms': 0.38,
#   'gap': 299,
#   'type': 'earthquake'},
#  {'id': 'pr2021031009',
#   'time': Timestamp('2021-01-31 17:33:19.360000'),
#   'updated': Timestamp('2021-01-31 17:57:23.479000'),
#   'latitude': 18.9663,
#   'longitude': -65.4251,
#   'depth_km': 66,
#   'mag': 3.04,
#   'magType': 'md',
#   'place': '72 km NNE of Luquillo, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 1,
#   'cdi': 0,
#   'mmi': None,
#   'sig': 142,
#   'net': 'pr',
#   'code': '2021031009',
#   'ids': ',pr2021031009,',
#   'sources': ',pr,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': 3,
#   'dmin': 0.8784,
#   'rms': 0.1,
#   'gap': 313,
#   'type': 'earthquake'},
#  {'id': 'us6000deuu',
#   'time': Timestamp('2021-01-31 16:42:37.236000'),
#   'updated': Timestamp('2021-04-16 19:03:45.040000'),
#   'latitude': -9.2887,
#   'longitude': 107.079,
#   'depth_km': 10,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': '234 km S of Banjar, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '6000deuu',
#   'ids': ',us6000deuu,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.9,
#   'rms': 0.45,
#   'gap': 162,
#   'type': 'earthquake'},
#  {'id': 'us6000deux',
#   'time': Timestamp('2021-01-31 16:22:11.061000'),
#   'updated': Timestamp('2021-04-16 19:03:45.040000'),
#   'latitude': -15.4811,
#   'longitude': -177.5456,
#   'depth_km': 405.32,
#   'mag': 4.1,
#   'magType': 'mb',
#   'place': '143 km SSE of Alo, Wallis and Futuna',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 259,
#   'net': 'us',
#   'code': '6000deux',
#   'ids': ',us6000deux,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 4.782,
#   'rms': 0.77,
#   'gap': 105,
#   'type': 'earthquake'},
#  {'id': 'us6000deut',
#   'time': Timestamp('2021-01-31 16:10:12.563000'),
#   'updated': Timestamp('2021-04-16 19:03:44.040000'),
#   'latitude': -57.4896,
#   'longitude': -25.1772,
#   'depth_km': 35,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': 'South Sandwich Islands region',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '6000deut',
#   'ids': ',us6000deut,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 16.972,
#   'rms': 0.56,
#   'gap': 68,
#   'type': 'earthquake'},
#  {'id': 'us6000ddfd',
#   'time': Timestamp('2021-01-31 16:04:33.562000'),
#   'updated': Timestamp('2021-04-16 19:02:39.040000'),
#   'latitude': 28.1239,
#   'longitude': 56.7043,
#   'depth_km': 10,
#   'mag': 4.9,
#   'magType': 'mww',
#   'place': '111 km NNE of Bandar Abbas, Iran',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 1,
#   'cdi': 4.3,
#   'mmi': None,
#   'sig': 370,
#   'net': 'us',
#   'code': '6000ddfd',
#   'ids': ',us6000ddfd,',
#   'sources': ',us,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': None,
#   'dmin': 3.197,
#   'rms': 0.7,
#   'gap': 72,
#   'type': 'earthquake'},
#  {'id': 'us6000ddfb',
#   'time': Timestamp('2021-01-31 15:51:49.658000'),
#   'updated': Timestamp('2021-04-16 19:02:38.040000'),
#   'latitude': 22.1851,
#   'longitude': 143.8711,
#   'depth_km': 132.47,
#   'mag': 4.9,
#   'magType': 'mb',
#   'place': 'Volcano Islands, Japan region',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 369,
#   'net': 'us',
#   'code': '6000ddfb',
#   'ids': ',us6000ddfb,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 5.124,
#   'rms': 0.7,
#   'gap': 99,
#   'type': 'earthquake'},
#  {'id': 'us6000deur',
#   'time': Timestamp('2021-01-31 15:50:10.756000'),
#   'updated': Timestamp('2021-04-16 19:03:44.040000'),
#   'latitude': -17.9997,
#   'longitude': -178.0067,
#   'depth_km': 522.9,
#   'mag': 4.5,
#   'magType': 'mb',
#   'place': '283 km E of Levuka, Fiji',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 312,
#   'net': 'us',
#   'code': '6000deur',
#   'ids': ',us6000deur,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 3.761,
#   'rms': 0.56,
#   'gap': 53,
#   'type': 'earthquake'},
#  {'id': 'pr2021031007',
#   'time': Timestamp('2021-01-31 15:14:16.130000'),
#   'updated': Timestamp('2021-04-16 19:02:38.040000'),
#   'latitude': 17.9611,
#   'longitude': -66.7563,
#   'depth_km': 7,
#   'mag': 3.03,
#   'magType': 'md',
#   'place': '5 km SW of Tallaboa, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 0,
#   'cdi': 1,
#   'mmi': None,
#   'sig': 141,
#   'net': 'pr',
#   'code': '2021031007',
#   'ids': ',pr2021031007,us6000ddf8,',
#   'sources': ',pr,us,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': 22,
#   'dmin': 0.1237,
#   'rms': 0.15,
#   'gap': 183,
#   'type': 'earthquake'},
#  {'id': 'us6000deuz',
#   'time': Timestamp('2021-01-31 14:53:34.962000'),
#   'updated': Timestamp('2021-04-16 19:03:46.040000'),
#   'latitude': -6.0792,
#   'longitude': 130.1556,
#   'depth_km': 180.18,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': '291 km W of Tual, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000deuz',
#   'ids': ',us6000deuz,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.205,
#   'rms': 0.33,
#   'gap': 115,
#   'type': 'earthquake'},
#  {'id': 'us6000ddf1',
#   'time': Timestamp('2021-01-31 14:41:05.024000'),
#   'updated': Timestamp('2021-04-16 19:02:38.040000'),
#   'latitude': -21.1257,
#   'longitude': -68.6639,
#   'depth_km': 126.73,
#   'mag': 4.1,
#   'magType': 'mb',
#   'place': '149 km N of Calama, Chile',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 259,
#   'net': 'us',
#   'code': '6000ddf1',
#   'ids': ',us6000ddf1,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.773,
#   'rms': 0.51,
#   'gap': 88,
#   'type': 'earthquake'},
#  {'id': 'us6000deuq',
#   'time': Timestamp('2021-01-31 13:21:11.897000'),
#   'updated': Timestamp('2021-04-16 19:03:44.040000'),
#   'latitude': 9.8175,
#   'longitude': 57.0807,
#   'depth_km': 10,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': 'Carlsberg Ridge',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 271,
#   'net': 'us',
#   'code': '6000deuq',
#   'ids': ',us6000deuq,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 15.069,
#   'rms': 0.87,
#   'gap': 123,
#   'type': 'earthquake'},
#  {'id': 'us6000di12',
#   'time': Timestamp('2021-01-31 12:13:50.596000'),
#   'updated': Timestamp('2021-04-16 19:04:33.040000'),
#   'latitude': 51.582,
#   'longitude': -177.5106,
#   'depth_km': 68.26,
#   'mag': 3.1,
#   'magType': 'ml',
#   'place': '68 km WSW of Adak, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 148,
#   'net': 'us',
#   'code': '6000di12',
#   'ids': ',ak0211fgvus4,us6000di12,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.247,
#   'rms': 0.2,
#   'gap': 213,
#   'type': 'earthquake'},
#  {'id': 'us6000ddeg',
#   'time': Timestamp('2021-01-31 12:13:10.524000'),
#   'updated': Timestamp('2021-04-16 19:02:37.040000'),
#   'latitude': -3.0174,
#   'longitude': 118.9466,
#   'depth_km': 10,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': '37 km S of Mamuju, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 1,
#   'cdi': 3.8,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000ddeg',
#   'ids': ',us6000ddeg,',
#   'sources': ',us,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': None,
#   'dmin': 2.139,
#   'rms': 0.46,
#   'gap': 128,
#   'type': 'earthquake'},
#  {'id': 'us6000deun',
#   'time': Timestamp('2021-01-31 11:48:46.726000'),
#   'updated': Timestamp('2021-04-16 19:03:43.040000'),
#   'latitude': 22.1544,
#   'longitude': 143.0202,
#   'depth_km': 213.55,
#   'mag': 4,
#   'magType': 'mb',
#   'place': 'Volcano Islands, Japan region',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 246,
#   'net': 'us',
#   'code': '6000deun',
#   'ids': ',us6000deun,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 4.978,
#   'rms': 0.51,
#   'gap': 160,
#   'type': 'earthquake'},
#  {'id': 'us6000deus',
#   'time': Timestamp('2021-01-31 11:15:51.488000'),
#   'updated': Timestamp('2021-04-16 19:03:44.040000'),
#   'latitude': -57.7066,
#   'longitude': -25.2659,
#   'depth_km': 49.93,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': 'South Sandwich Islands region',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000deus',
#   'ids': ',us6000deus,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 16.794,
#   'rms': 0.6,
#   'gap': 128,
#   'type': 'earthquake'},
#  {'id': 'us6000dddu',
#   'time': Timestamp('2021-01-31 09:44:41.934000'),
#   'updated': Timestamp('2025-12-22 18:49:11.074000'),
#   'latitude': -5.5312,
#   'longitude': 133.7606,
#   'depth_km': 10,
#   'mag': 5.3,
#   'magType': 'mww',
#   'place': '112 km E of Tual, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 432,
#   'net': 'us',
#   'code': '6000dddu',
#   'ids': ',us6000dddu,iscgem619782090,',
#   'sources': ',us,iscgem,',
#   'types': ',moment-tensor,origin,phase-data,',
#   'nst': None,
#   'dmin': 3,
#   'rms': 0.79,
#   'gap': 57,
#   'type': 'earthquake'},
#  {'id': 'us6000dddp',
#   'time': Timestamp('2021-01-31 09:28:50.798000'),
#   'updated': Timestamp('2021-04-16 19:02:36.040000'),
#   'latitude': -5.558,
#   'longitude': 133.7996,
#   'depth_km': 10,
#   'mag': 4.8,
#   'magType': 'mb',
#   'place': '116 km E of Tual, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 1,
#   'cdi': 3.1,
#   'mmi': None,
#   'sig': 355,
#   'net': 'us',
#   'code': '6000dddp',
#   'ids': ',us6000dddp,',
#   'sources': ',us,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': None,
#   'dmin': 3.043,
#   'rms': 0.76,
#   'gap': 73,
#   'type': 'earthquake'},
#  {'id': 'us6000deuk',
#   'time': Timestamp('2021-01-31 08:59:04.795000'),
#   'updated': Timestamp('2021-04-16 19:03:43.040000'),
#   'latitude': -35.6162,
#   'longitude': 179.5764,
#   'depth_km': 35,
#   'mag': 4.3,
#   'magType': 'mb',
#   'place': 'off the east coast of the North Island of New Zealand',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '6000deuk',
#   'ids': ',us6000deuk,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 10.413,
#   'rms': 1.01,
#   'gap': 197,
#   'type': 'earthquake'},
#  {'id': 'pr2021031001',
#   'time': Timestamp('2021-01-31 08:42:12.430000'),
#   'updated': Timestamp('2021-01-31 09:56:10.821000'),
#   'latitude': 18.2898,
#   'longitude': -67.2835,
#   'depth_km': 120,
#   'mag': 3.22,
#   'magType': 'md',
#   'place': '5 km SW of Stella, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 160,
#   'net': 'pr',
#   'code': '2021031001',
#   'ids': ',pr2021031001,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 12,
#   'dmin': 0.1566,
#   'rms': 0.36,
#   'gap': 294,
#   'type': 'earthquake'},
#  {'id': 'us6000di0x',
#   'time': Timestamp('2021-01-31 05:26:44.018000'),
#   'updated': Timestamp('2021-04-16 19:04:32.040000'),
#   'latitude': 54.3987,
#   'longitude': -159.6886,
#   'depth_km': 24.36,
#   'mag': 3.3,
#   'magType': 'mb',
#   'place': '116 km SSE of Sand Point, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 168,
#   'net': 'us',
#   'code': '6000di0x',
#   'ids': ',ak0211fcsl8p,us6000di0x,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.437,
#   'rms': 0.46,
#   'gap': 200,
#   'type': 'earthquake'},
#  {'id': 'pr2021031029',
#   'time': Timestamp('2021-01-31 05:19:39.390000'),
#   'updated': Timestamp('2023-02-10 00:50:29.212000'),
#   'latitude': 18.4505,
#   'longitude': -68.3773,
#   'depth_km': 176,
#   'mag': 3.36,
#   'magType': 'md',
#   'place': '14 km S of Punta Cana, Dominican Republic',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 174,
#   'net': 'pr',
#   'code': '2021031029',
#   'ids': ',pr2021031029,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 5,
#   'dmin': 1.4172,
#   'rms': 0.29,
#   'gap': 343,
#   'type': 'earthquake'},
#  {'id': 'us6000ddct',
#   'time': Timestamp('2021-01-31 05:11:02.837000'),
#   'updated': Timestamp('2023-01-16 19:15:52.957000'),
#   'latitude': 21.7592,
#   'longitude': 145.4953,
#   'depth_km': 10,
#   'mag': 5,
#   'magType': 'mb',
#   'place': 'Mariana Islands region',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 385,
#   'net': 'us',
#   'code': '6000ddct',
#   'ids': ',us6000ddct,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 6.109,
#   'rms': 0.51,
#   'gap': 114,
#   'type': 'earthquake'},
#  {'id': 'us6000deuh',
#   'time': Timestamp('2021-01-31 05:02:44.783000'),
#   'updated': Timestamp('2021-04-16 19:03:43.040000'),
#   'latitude': 9.4274,
#   'longitude': 125.8907,
#   'depth_km': 71.09,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': '2 km NNW of Adlay, Philippines',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 271,
#   'net': 'us',
#   'code': '6000deuh',
#   'ids': ',us6000deuh,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.362,
#   'rms': 0.6,
#   'gap': 137,
#   'type': 'earthquake'},
#  {'id': 'us6000ddcd',
#   'time': Timestamp('2021-01-31 03:59:26.980000'),
#   'updated': Timestamp('2025-12-22 18:49:10.382000'),
#   'latitude': -24.2599,
#   'longitude': -66.9195,
#   'depth_km': 170.88,
#   'mag': 4.9,
#   'magType': 'mww',
#   'place': '61 km W of San Antonio de los Cobres, Argentina',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 2,
#   'cdi': 3.1,
#   'mmi': None,
#   'sig': 370,
#   'net': 'us',
#   'code': '6000ddcd',
#   'ids': ',us6000ddcd,iscgem619782085,',
#   'sources': ',us,iscgem,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': None,
#   'dmin': 1.74,
#   'rms': 1.23,
#   'gap': 29,
#   'type': 'earthquake'},
#  {'id': 'us6000deue',
#   'time': Timestamp('2021-01-31 02:30:06.536000'),
#   'updated': Timestamp('2021-04-16 19:03:42.040000'),
#   'latitude': -15.6676,
#   'longitude': 167.221,
#   'depth_km': 35,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': '17 km SSE of Luganville, Vanuatu',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000deue',
#   'ids': ',us6000deue,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 17.919,
#   'rms': 1.13,
#   'gap': 134,
#   'type': 'earthquake'},
#  {'id': 'us6000ddbs',
#   'time': Timestamp('2021-01-31 01:33:03.171000'),
#   'updated': Timestamp('2021-04-16 19:02:34.040000'),
#   'latitude': -22.9046,
#   'longitude': -179.4621,
#   'depth_km': 527.31,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': 'south of the Fiji Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '6000ddbs',
#   'ids': ',us6000ddbs,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 6.462,
#   'rms': 0.81,
#   'gap': 110,
#   'type': 'earthquake'},
#  {'id': 'us6000deud',
#   'time': Timestamp('2021-01-31 01:16:58.012000'),
#   'updated': Timestamp('2021-04-16 19:03:42.040000'),
#   'latitude': -7.2149,
#   'longitude': 67.9614,
#   'depth_km': 10,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': 'Mid-Indian Ridge',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000deud',
#   'ids': ',us6000deud,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 39.813,
#   'rms': 0.44,
#   'gap': 118,
#   'type': 'earthquake'},
#  {'id': 'us6000di0t',
#   'time': Timestamp('2021-01-31 01:00:19.089000'),
#   'updated': Timestamp('2021-04-16 19:04:31.040000'),
#   'latitude': 53.2669,
#   'longitude': -160.4649,
#   'depth_km': 10,
#   'mag': 3,
#   'magType': 'ml',
#   'place': '230 km S of Sand Point, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 138,
#   'net': 'us',
#   'code': '6000di0t',
#   'ids': ',ak0211fa99kg,us6000di0t,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.65,
#   'rms': 0.4,
#   'gap': 231,
#   'type': 'earthquake'},
#  {'id': 'us6000ddbj',
#   'time': Timestamp('2021-01-31 00:53:29.220000'),
#   'updated': Timestamp('2021-04-16 19:02:34.040000'),
#   'latitude': -24.9922,
#   'longitude': 179.5587,
#   'depth_km': 523.43,
#   'mag': 4.3,
#   'magType': 'mb',
#   'place': 'south of the Fiji Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '6000ddbj',
#   'ids': ',us6000ddbj,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 11.388,
#   'rms': 0.75,
#   'gap': 112,
#   'type': 'earthquake'},
#  {'id': 'us6000ddbf',
#   'time': Timestamp('2021-01-31 00:34:14.635000'),
#   'updated': Timestamp('2021-04-16 19:02:34.040000'),
#   'latitude': 9.0919,
#   'longitude': 126.5574,
#   'depth_km': 18.17,
#   'mag': 4.9,
#   'magType': 'mb',
#   'place': '34 km ENE of Bacolod, Philippines',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 369,
#   'net': 'us',
#   'code': '6000ddbf',
#   'ids': ',us6000ddbf,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.23,
#   'rms': 0.52,
#   'gap': 108,
#   'type': 'earthquake'},
#  {'id': 'us6000di0s',
#   'time': Timestamp('2021-01-31 00:01:27.444000'),
#   'updated': Timestamp('2021-04-16 19:04:31.040000'),
#   'latitude': 51.9539,
#   'longitude': -169.9666,
#   'depth_km': 26.87,
#   'mag': 3.1,
#   'magType': 'ml',
#   'place': '132 km SW of Nikolski, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 148,
#   'net': 'us',
#   'code': '6000di0s',
#   'ids': ',ak0211f9o16x,us6000di0s,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.847,
#   'rms': 0.43,
#   'gap': 224,
#   'type': 'earthquake'},
#  {'id': 'us6000ddal',
#   'time': Timestamp('2021-01-30 20:01:38.678000'),
#   'updated': Timestamp('2021-04-16 19:02:33.040000'),
#   'latitude': 43.7675,
#   'longitude': -105.2767,
#   'depth_km': 0,
#   'mag': 3.2,
#   'magType': 'ml',
#   'place': '17 km E of Wright, Wyoming',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 158,
#   'net': 'us',
#   'code': '6000ddal',
#   'ids': ',us6000ddal,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.963,
#   'rms': 0.65,
#   'gap': 81,
#   'type': 'mining explosion'},
#  {'id': 'us6000dess',
#   'time': Timestamp('2021-01-30 19:43:01.945000'),
#   'updated': Timestamp('2021-04-16 19:03:42.040000'),
#   'latitude': -7.2877,
#   'longitude': 128.5855,
#   'depth_km': 151.91,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': '221 km NE of Lospalos, Timor Leste',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 271,
#   'net': 'us',
#   'code': '6000dess',
#   'ids': ',us6000dess,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.776,
#   'rms': 1.06,
#   'gap': 73,
#   'type': 'earthquake'},
#  {'id': 'pr2021030110',
#   'time': Timestamp('2021-01-30 19:31:25.840000'),
#   'updated': Timestamp('2022-12-02 00:43:40.178000'),
#   'latitude': 18.5761,
#   'longitude': -67.2585,
#   'depth_km': 118,
#   'mag': 3.39,
#   'magType': 'md',
#   'place': '19 km WNW of San Antonio, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 177,
#   'net': 'pr',
#   'code': '2021030110',
#   'ids': ',pr2021030110,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 3,
#   'dmin': 0.5888,
#   'rms': 0.07,
#   'gap': 301,
#   'type': 'earthquake'},
#  {'id': 'us6000desi',
#   'time': Timestamp('2021-01-30 19:16:43.754000'),
#   'updated': Timestamp('2021-04-16 19:03:41.040000'),
#   'latitude': 5.1441,
#   'longitude': 127.3417,
#   'depth_km': 120.08,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': '186 km SE of Pondaguitan, Philippines',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000desi',
#   'ids': ',us6000desi,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.594,
#   'rms': 0.68,
#   'gap': 112,
#   'type': 'earthquake'},
#  {'id': 'us6000desg',
#   'time': Timestamp('2021-01-30 19:08:13.613000'),
#   'updated': Timestamp('2021-04-16 19:03:41.040000'),
#   'latitude': -11.4184,
#   'longitude': 165.5406,
#   'depth_km': 10,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': '81 km SSW of Lata, Solomon Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000desg',
#   'ids': ',us6000desg,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 5.842,
#   'rms': 0.72,
#   'gap': 146,
#   'type': 'earthquake'},
#  {'id': 'us6000desf',
#   'time': Timestamp('2021-01-30 18:15:34.214000'),
#   'updated': Timestamp('2021-04-16 19:03:41.040000'),
#   'latitude': 13.4748,
#   'longitude': 119.2556,
#   'depth_km': 10,
#   'mag': 4,
#   'magType': 'mb',
#   'place': '97 km WSW of Cabra, Philippines',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 246,
#   'net': 'us',
#   'code': '6000desf',
#   'ids': ',us6000desf,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 9.859,
#   'rms': 0.54,
#   'gap': 145,
#   'type': 'earthquake'},
#  {'id': 'us6000dh6y',
#   'time': Timestamp('2021-01-30 17:50:17.105000'),
#   'updated': Timestamp('2021-04-16 19:04:21.040000'),
#   'latitude': 53.5037,
#   'longitude': -165.3254,
#   'depth_km': 35,
#   'mag': 3.4,
#   'magType': 'ml',
#   'place': '76 km SSE of Akutan, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 178,
#   'net': 'us',
#   'code': '6000dh6y',
#   'ids': ',ak0211dwjjd3,us6000dh6y,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.678,
#   'rms': 0.58,
#   'gap': 190,
#   'type': 'earthquake'},
#  {'id': 'us6000dd9y',
#   'time': Timestamp('2021-01-30 17:23:27.207000'),
#   'updated': Timestamp('2021-04-16 19:02:32.040000'),
#   'latitude': 26.84,
#   'longitude': 53.9755,
#   'depth_km': 10,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': '31 km N of K?sh, Iran',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 271,
#   'net': 'us',
#   'code': '6000dd9y',
#   'ids': ',us6000dd9y,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.754,
#   'rms': 0.79,
#   'gap': 76,
#   'type': 'earthquake'},
#  {'id': 'us6000dese',
#   'time': Timestamp('2021-01-30 17:13:28.217000'),
#   'updated': Timestamp('2021-04-16 19:03:40.040000'),
#   'latitude': -26.2492,
#   'longitude': 70.969,
#   'depth_km': 10,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': 'Indian Ocean Triple Junction',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000dese',
#   'ids': ',us6000dese,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 49.916,
#   'rms': 0.45,
#   'gap': 173,
#   'type': 'earthquake'},
#  {'id': 'us6000desd',
#   'time': Timestamp('2021-01-30 17:00:58.604000'),
#   'updated': Timestamp('2021-04-16 19:03:40.040000'),
#   'latitude': 0.5312,
#   'longitude': 125.5284,
#   'depth_km': 57.12,
#   'mag': 5,
#   'magType': 'mb',
#   'place': '109 km SE of Tondano, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 385,
#   'net': 'us',
#   'code': '6000desd',
#   'ids': ',us6000desd,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.853,
#   'rms': 1.05,
#   'gap': 48,
#   'type': 'earthquake'},
#  {'id': 'us6000desb',
#   'time': Timestamp('2021-01-30 15:39:39.847000'),
#   'updated': Timestamp('2021-04-16 19:03:40.040000'),
#   'latitude': -8.2562,
#   'longitude': 156.4859,
#   'depth_km': 10,
#   'mag': 4.5,
#   'magType': 'mb',
#   'place': '42 km WSW of Gizo, Solomon Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 312,
#   'net': 'us',
#   'code': '6000desb',
#   'ids': ',us6000desb,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 3.617,
#   'rms': 1.23,
#   'gap': 88,
#   'type': 'earthquake'},
#  {'id': 'us6000dd9d',
#   'time': Timestamp('2021-01-30 15:36:50.734000'),
#   'updated': Timestamp('2021-04-16 19:02:31.040000'),
#   'latitude': -62.238,
#   'longitude': -57.6176,
#   'depth_km': 10,
#   'mag': 5,
#   'magType': 'mb',
#   'place': 'South Shetland Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 385,
#   'net': 'us',
#   'code': '6000dd9d',
#   'ids': ',us6000dd9d,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.199,
#   'rms': 1.03,
#   'gap': 84,
#   'type': 'earthquake'},
#  {'id': 'us6000desj',
#   'time': Timestamp('2021-01-30 14:34:56.093000'),
#   'updated': Timestamp('2021-04-16 19:03:41.040000'),
#   'latitude': -9.1744,
#   'longitude': 110.3448,
#   'depth_km': 57.04,
#   'mag': 4.3,
#   'magType': 'mb',
#   'place': '135 km S of Pundong, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '6000desj',
#   'ids': ',us6000desj,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.266,
#   'rms': 0.76,
#   'gap': 122,
#   'type': 'earthquake'},
#  {'id': 'us6000dd90',
#   'time': Timestamp('2021-01-30 14:19:28.479000'),
#   'updated': Timestamp('2021-04-16 19:02:30.040000'),
#   'latitude': 47.2958,
#   'longitude': 152.4685,
#   'depth_km': 106.89,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': 'Kuril Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '6000dd90',
#   'ids': ',us6000dd90,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 6.633,
#   'rms': 0.94,
#   'gap': 118,
#   'type': 'earthquake'},
#  {'id': 'pr2021030099',
#   'time': Timestamp('2021-01-30 14:11:24.600000'),
#   'updated': Timestamp('2022-10-20 18:42:04.790000'),
#   'latitude': 19.5746,
#   'longitude': -65.705,
#   'depth_km': 13,
#   'mag': 3.58,
#   'magType': 'md',
#   'place': '127 km N of Suárez, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 197,
#   'net': 'pr',
#   'code': '2021030099',
#   'ids': ',pr2021030099,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 4,
#   'dmin': 1.4397,
#   'rms': 0.09,
#   'gap': 324,
#   'type': 'earthquake'},
#  {'id': 'us6000dd8q',
#   'time': Timestamp('2021-01-30 13:29:26.068000'),
#   'updated': Timestamp('2021-04-16 19:02:30.040000'),
#   'latitude': -5.7369,
#   'longitude': 148.526,
#   'depth_km': 134.81,
#   'mag': 4.5,
#   'magType': 'mb',
#   'place': '117 km NE of Finschhafen, Papua New Guinea',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 312,
#   'net': 'us',
#   'code': '6000dd8q',
#   'ids': ',us6000dd8q,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 3.847,
#   'rms': 0.98,
#   'gap': 65,
#   'type': 'earthquake'},
#  {'id': 'us6000dd81',
#   'time': Timestamp('2021-01-30 13:24:59.060000'),
#   'updated': Timestamp('2025-12-22 18:49:09.617000'),
#   'latitude': -19.9589,
#   'longitude': -70.3542,
#   'depth_km': 58.5,
#   'mag': 5.2,
#   'magType': 'mww',
#   'place': '35 km NW of Iquique, Chile',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 54,
#   'cdi': 4.6,
#   'mmi': None,
#   'sig': 441,
#   'net': 'us',
#   'code': '6000dd81',
#   'ids': ',us6000dd81,iscgem619781989,',
#   'sources': ',us,iscgem,',
#   'types': ',dyfi,moment-tensor,origin,phase-data,',
#   'nst': None,
#   'dmin': 0.625,
#   'rms': 0.96,
#   'gap': 136,
#   'type': 'earthquake'},
#  {'id': 'us6000dd7w',
#   'time': Timestamp('2021-01-30 13:16:12.874000'),
#   'updated': Timestamp('2021-04-16 19:02:29.040000'),
#   'latitude': -29.4025,
#   'longitude': -71.1292,
#   'depth_km': 57.83,
#   'mag': 4.3,
#   'magType': 'mwr',
#   'place': '56 km NNE of La Serena, Chile',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '6000dd7w',
#   'ids': ',us6000dd7w,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.523,
#   'rms': 0.54,
#   'gap': 118,
#   'type': 'earthquake'},
#  {'id': 'us6000dd7v',
#   'time': Timestamp('2021-01-30 12:50:45.883000'),
#   'updated': Timestamp('2021-04-16 19:02:29.040000'),
#   'latitude': 48.7427,
#   'longitude': 153.0536,
#   'depth_km': 160.15,
#   'mag': 4.4,
#   'magType': 'mb',
#   'place': 'Kuril Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 298,
#   'net': 'us',
#   'code': '6000dd7v',
#   'ids': ',us6000dd7v,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 5.265,
#   'rms': 0.6,
#   'gap': 134,
#   'type': 'earthquake'},
#  {'id': 'us6000dh6k',
#   'time': Timestamp('2021-01-30 12:09:45.614000'),
#   'updated': Timestamp('2021-04-16 19:04:18.040000'),
#   'latitude': 52.7669,
#   'longitude': -168.2204,
#   'depth_km': 35,
#   'mag': 3.3,
#   'magType': 'ml',
#   'place': '47 km ESE of Nikolski, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 168,
#   'net': 'us',
#   'code': '6000dh6k',
#   'ids': ',ak0211dtbn42,us6000dh6k,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.487,
#   'rms': 0.47,
#   'gap': 207,
#   'type': 'earthquake'},
#  {'id': 'us6000des3',
#   'time': Timestamp('2021-01-30 11:45:54.258000'),
#   'updated': Timestamp('2021-04-16 19:03:39.040000'),
#   'latitude': -50.1928,
#   'longitude': 112.6758,
#   'depth_km': 10,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': 'southeast Indian Ridge',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '6000des3',
#   'ids': ',us6000des3,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 24.502,
#   'rms': 0.95,
#   'gap': 109,
#   'type': 'earthquake'},
#  {'id': 'us6000dd7l',
#   'time': Timestamp('2021-01-30 10:52:31.473000'),
#   'updated': Timestamp('2025-12-22 17:59:54.792000'),
#   'latitude': -4.5295,
#   'longitude': 102.5048,
#   'depth_km': 54.9,
#   'mag': 4.9,
#   'magType': 'mww',
#   'place': '84 km SSE of Bengkulu, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': 'green',
#   'felt': 1,
#   'cdi': 2.7,
#   'mmi': 3.207,
#   'sig': 370,
#   'net': 'us',
#   'code': '6000dd7l',
#   'ids': ',us6000dd7l,iscgem619781983,',
#   'sources': ',us,iscgem,',
#   'types': ',dyfi,losspager,origin,phase-data,shakemap,',
#   'nst': None,
#   'dmin': 0.479,
#   'rms': 0.57,
#   'gap': 31,
#   'type': 'earthquake'},
#  {'id': 'us6000derz',
#   'time': Timestamp('2021-01-30 10:49:11.296000'),
#   'updated': Timestamp('2021-04-16 19:03:39.040000'),
#   'latitude': -6.5823,
#   'longitude': 71.2525,
#   'depth_km': 10,
#   'mag': 4.5,
#   'magType': 'mb',
#   'place': 'Chagos Archipelago region',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 312,
#   'net': 'us',
#   'code': '6000derz',
#   'ids': ',us6000derz,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.455,
#   'rms': 0.47,
#   'gap': 88,
#   'type': 'earthquake'},
#  {'id': 'us6000dd7d',
#   'time': Timestamp('2021-01-30 09:50:05.528000'),
#   'updated': Timestamp('2021-04-16 19:02:28.040000'),
#   'latitude': 1.5398,
#   'longitude': 121.9731,
#   'depth_km': 480.99,
#   'mag': 4.5,
#   'magType': 'mb',
#   'place': '164 km NW of Gorontalo, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 312,
#   'net': 'us',
#   'code': '6000dd7d',
#   'ids': ',us6000dd7d,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.264,
#   'rms': 0.74,
#   'gap': 52,
#   'type': 'earthquake'},
#  {'id': 'us6000derw',
#   'time': Timestamp('2021-01-30 09:31:47.418000'),
#   'updated': Timestamp('2021-04-16 19:03:38.040000'),
#   'latitude': -11.7454,
#   'longitude': 166.6071,
#   'depth_km': 39.38,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': '143 km SE of Lata, Solomon Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 271,
#   'net': 'us',
#   'code': '6000derw',
#   'ids': ',us6000derw,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 6.936,
#   'rms': 0.39,
#   'gap': 84,
#   'type': 'earthquake'},
#  {'id': 'us6000dd79',
#   'time': Timestamp('2021-01-30 09:10:29.848000'),
#   'updated': Timestamp('2021-04-16 19:02:27.040000'),
#   'latitude': 31.6682,
#   'longitude': -104.4117,
#   'depth_km': 5,
#   'mag': 3.4,
#   'magType': 'ml',
#   'place': '56 km S of Whites City, New Mexico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 3,
#   'cdi': 3.4,
#   'mmi': 4.071,
#   'sig': 179,
#   'net': 'us',
#   'code': '6000dd79',
#   'ids': ',us6000dd79,',
#   'sources': ',us,',
#   'types': ',dyfi,origin,phase-data,shakemap,',
#   'nst': None,
#   'dmin': 0.075,
#   'rms': 0.52,
#   'gap': 61,
#   'type': 'earthquake'},
#  {'id': 'us6000dery',
#   'time': Timestamp('2021-01-30 09:06:44.294000'),
#   'updated': Timestamp('2021-04-16 19:03:39.040000'),
#   'latitude': 4.6586,
#   'longitude': 96.3415,
#   'depth_km': 10,
#   'mag': 4.3,
#   'magType': 'mb',
#   'place': '61 km NNE of Meulaboh, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '6000dery',
#   'ids': ',us6000dery,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.827,
#   'rms': 0.41,
#   'gap': 152,
#   'type': 'earthquake'},
#  {'id': 'pr2021030076',
#   'time': Timestamp('2021-01-30 08:51:04.360000'),
#   'updated': Timestamp('2022-10-06 22:59:26.335000'),
#   'latitude': 19.0731,
#   'longitude': -67.1653,
#   'depth_km': 93,
#   'mag': 3.48,
#   'magType': 'md',
#   'place': '64 km N of San Antonio, Puerto Rico',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 186,
#   'net': 'pr',
#   'code': '2021030076',
#   'ids': ',pr2021030076,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 8,
#   'dmin': 0.8348,
#   'rms': 0.32,
#   'gap': 237,
#   'type': 'earthquake'},
#  {'id': 'us6000dd74',
#   'time': Timestamp('2021-01-30 08:35:16.603000'),
#   'updated': Timestamp('2025-12-22 18:49:08.819000'),
#   'latitude': 54.1649,
#   'longitude': 169.2391,
#   'depth_km': 19.19,
#   'mag': 5.3,
#   'magType': 'mww',
#   'place': 'Komandorskiye Ostrova, Russia region',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 432,
#   'net': 'us',
#   'code': '6000dd74',
#   'ids': ',us6000dd74,iscgem619781864,',
#   'sources': ',us,iscgem,',
#   'types': ',moment-tensor,origin,phase-data,',
#   'nst': None,
#   'dmin': 3.242,
#   'rms': 0.73,
#   'gap': 82,
#   'type': 'earthquake'},
# ...
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.059,
#   'rms': 0.83,
#   'gap': 59,
#   'type': 'earthquake'},
#  {'id': 'pr2021014106',
#   'time': Timestamp('2021-01-14 19:52:52.420000'),
#   'updated': Timestamp('2021-05-11 17:14:27.849000'),
#   'latitude': 19.1951,
#   'longitude': -64.9671,
#   'depth_km': 44,
#   'mag': 3.34,
#   'magType': 'md',
#   'place': '94 km N of Charlotte Amalie, U.S. Virgin Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 172,
#   'net': 'pr',
#   'code': '2021014106',
#   'ids': ',pr2021014106,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 4,
#   'dmin': 1.2442,
#   'rms': 0.19,
#   'gap': 331,
#   'type': 'earthquake'},
#  {'id': 'us7000d2ec',
#   'time': Timestamp('2021-01-14 19:47:55.857000'),
#   'updated': Timestamp('2021-03-20 21:25:49.040000'),
#   'latitude': 0.4802,
#   'longitude': 99.7605,
#   'depth_km': 133.92,
#   'mag': 4.3,
#   'magType': 'mb',
#   'place': '110 km NW of Bukittinggi, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '7000d2ec',
#   'ids': ',us7000d2ec,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.332,
#   'rms': 0.43,
#   'gap': 144,
#   'type': 'earthquake'},
#  {'id': 'us7000d2eb',
#   'time': Timestamp('2021-01-14 19:34:56.515000'),
#   'updated': Timestamp('2021-03-20 21:25:49.040000'),
#   'latitude': 38.9732,
#   'longitude': 144.4559,
#   'depth_km': 10,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': '223 km ESE of Yamada, Japan',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 271,
#   'net': 'us',
#   'code': '7000d2eb',
#   'ids': ',us7000d2eb,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 3.177,
#   'rms': 0.81,
#   'gap': 209,
#   'type': 'earthquake'},
#  {'id': 'us7000d03l',
#   'time': Timestamp('2021-01-14 19:29:51.332000'),
#   'updated': Timestamp('2021-03-20 21:25:49.040000'),
#   'latitude': 51.2346,
#   'longitude': 100.5809,
#   'depth_km': 10,
#   'mag': 4.3,
#   'magType': 'mb',
#   'place': '30 km S of Turt, Mongolia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '7000d03l',
#   'ids': ',us7000d03l,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.967,
#   'rms': 0.7,
#   'gap': 42,
#   'type': 'earthquake'},
#  {'id': 'nc73510910',
#   'time': Timestamp('2021-01-14 19:18:10.680000'),
#   'updated': Timestamp('2025-01-12 17:56:15.574000'),
#   'latitude': 37.9708333,
#   'longitude': -122.0406667,
#   'depth_km': 15.24,
#   'mag': 3.63,
#   'magType': 'mw',
#   'place': '2km W of Concord, CA',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 3784,
#   'cdi': 4.3,
#   'mmi': 3.323,
#   'sig': 633,
#   'net': 'nc',
#   'code': '73510910',
#   'ids': ',nc73510910,us7000d03i,',
#   'sources': ',nc,us,',
#   'types': ',dyfi,focal-mechanism,moment-tensor,nearby-cities,origin,phase-data,scitech-link,shakemap,',
#   'nst': 199,
#   'dmin': 0.002813,
#   'rms': 0.19,
#   'gap': 29,
#   'type': 'earthquake'},
#  {'id': 'pr2021014100',
#   'time': Timestamp('2021-01-14 18:40:02.730000'),
#   'updated': Timestamp('2021-05-11 17:17:17.537000'),
#   'latitude': 18.861,
#   'longitude': -64.7358,
#   'depth_km': 38,
#   'mag': 3.23,
#   'magType': 'md',
#   'place': '58 km N of Cruz Bay, U.S. Virgin Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 161,
#   'net': 'pr',
#   'code': '2021014100',
#   'ids': ',pr2021014100,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 3,
#   'dmin': 1.1182,
#   'rms': 0.09,
#   'gap': 349,
#   'type': 'earthquake'},
#  {'id': 'us7000d030',
#   'time': Timestamp('2021-01-14 18:28:18.093000'),
#   'updated': Timestamp('2025-12-22 18:48:23.045000'),
#   'latitude': -2.9717,
#   'longitude': 118.8899,
#   'depth_km': 18,
#   'mag': 6.2,
#   'magType': 'mww',
#   'place': '32 km S of Mamuju, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': 'green',
#   'felt': 16,
#   'cdi': 8.6,
#   'mmi': 7.034,
#   'sig': 600,
#   'net': 'us',
#   'code': '7000d030',
#   'ids': ',us7000d030,usauto7000d030,pt21014001,at00qmxsna,iscgem619717479,',
#   'sources': ',us,usauto,pt,at,iscgem,',
#   'types': ',dyfi,general-text,ground-failure,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,significance,',
#   'nst': None,
#   'dmin': 2.203,
#   'rms': 1.12,
#   'gap': 28,
#   'type': 'earthquake'},
#  {'id': 'us7000d02y',
#   'time': Timestamp('2021-01-14 18:26:39.325000'),
#   'updated': Timestamp('2021-03-20 21:25:44.040000'),
#   'latitude': 47.6223,
#   'longitude': -92.6147,
#   'depth_km': 0,
#   'mag': 3.2,
#   'magType': 'ml',
#   'place': '10 km N of Mountain Iron, Minnesota',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 158,
#   'net': 'us',
#   'code': '7000d02y',
#   'ids': ',us7000d02y,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.821,
#   'rms': 0.77,
#   'gap': 83,
#   'type': 'mining explosion'},
#  {'id': 'pr2021014094',
#   'time': Timestamp('2021-01-14 18:15:27.390000'),
#   'updated': Timestamp('2021-05-11 08:02:09.494000'),
#   'latitude': 18.1973,
#   'longitude': -68.3763,
#   'depth_km': 116,
#   'mag': 3.44,
#   'magType': 'md',
#   'place': '31 km SE of Boca de Yuma, Dominican Republic',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 182,
#   'net': 'pr',
#   'code': '2021014094',
#   'ids': ',pr2021014094,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 11,
#   'dmin': 0.9165,
#   'rms': 0.4,
#   'gap': 171,
#   'type': 'earthquake'},
#  {'id': 'us7000d2ea',
#   'time': Timestamp('2021-01-14 17:59:21.998000'),
#   'updated': Timestamp('2021-03-20 21:25:44.040000'),
#   'latitude': -15.7736,
#   'longitude': -174.6848,
#   'depth_km': 252.66,
#   'mag': 4.1,
#   'magType': 'mb',
#   'place': '97 km WNW of Hihifo, Tonga',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 259,
#   'net': 'us',
#   'code': '7000d2ea',
#   'ids': ',us7000d2ea,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 3.363,
#   'rms': 0.85,
#   'gap': 76,
#   'type': 'earthquake'},
#  {'id': 'pr2021014093',
#   'time': Timestamp('2021-01-14 17:55:19.300000'),
#   'updated': Timestamp('2021-05-11 08:01:16.718000'),
#   'latitude': 19.1861,
#   'longitude': -65.0226,
#   'depth_km': 46,
#   'mag': 3.39,
#   'magType': 'md',
#   'place': '93 km N of Charlotte Amalie, U.S. Virgin Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 177,
#   'net': 'pr',
#   'code': '2021014093',
#   'ids': ',pr2021014093,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 6,
#   'dmin': 1.2109,
#   'rms': 0.49,
#   'gap': 325,
#   'type': 'earthquake'},
#  {'id': 'us7000d02v',
#   'time': Timestamp('2021-01-14 17:20:31.010000'),
#   'updated': Timestamp('2021-03-20 21:25:43.040000'),
#   'latitude': 73.5242,
#   'longitude': 8.015,
#   'depth_km': 10,
#   'mag': 4.3,
#   'magType': 'mb',
#   'place': 'Greenland Sea',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 284,
#   'net': 'us',
#   'code': '7000d02v',
#   'ids': ',us7000d02v,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 5.099,
#   'rms': 0.79,
#   'gap': 80,
#   'type': 'earthquake'},
#  {'id': 'us7000d3mn',
#   'time': Timestamp('2021-01-14 17:08:15.225000'),
#   'updated': Timestamp('2021-03-20 21:25:43.040000'),
#   'latitude': 55.0017,
#   'longitude': -159.3449,
#   'depth_km': 11.4,
#   'mag': 3.1,
#   'magType': 'ml',
#   'place': '82 km ESE of Sand Point, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 148,
#   'net': 'us',
#   'code': '7000d3mn',
#   'ids': ',ak021nfoz4o,us7000d3mn,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.221,
#   'rms': 0.84,
#   'gap': 169,
#   'type': 'earthquake'},
#  {'id': 'us7000d02l',
#   'time': Timestamp('2021-01-14 16:50:56.805000'),
#   'updated': Timestamp('2021-03-20 21:25:43.040000'),
#   'latitude': 1.2727,
#   'longitude': 96.8714,
#   'depth_km': 10,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': '144 km SSE of Sinabang, Indonesia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '7000d02l',
#   'ids': ',us7000d02l,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.704,
#   'rms': 0.84,
#   'gap': 155,
#   'type': 'earthquake'},
#  {'id': 'us7000d02g',
#   'time': Timestamp('2021-01-14 16:28:10.875000'),
#   'updated': Timestamp('2021-03-20 21:25:42.040000'),
#   'latitude': 25.4342,
#   'longitude': 124.3328,
#   'depth_km': 118.25,
#   'mag': 4.7,
#   'magType': 'mwr',
#   'place': '120 km NW of Hirara, Japan',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 340,
#   'net': 'us',
#   'code': '7000d02g',
#   'ids': ',us7000d02g,',
#   'sources': ',us,',
#   'types': ',moment-tensor,origin,phase-data,',
#   'nst': None,
#   'dmin': 1.538,
#   'rms': 0.78,
#   'gap': 77,
#   'type': 'earthquake'},
#  {'id': 'us7000d3mm',
#   'time': Timestamp('2021-01-14 16:08:44.506000'),
#   'updated': Timestamp('2021-03-20 21:25:42.040000'),
#   'latitude': 56.1224,
#   'longitude': -149.7226,
#   'depth_km': 20.41,
#   'mag': 3.3,
#   'magType': 'ml',
#   'place': '227 km SE of Chiniak, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 168,
#   'net': 'us',
#   'code': '7000d3mm',
#   'ids': ',ak021nf3m75,us7000d3mm,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.255,
#   'rms': 0.83,
#   'gap': 206,
#   'type': 'earthquake'},
#  {'id': 'us7000d028',
#   'time': Timestamp('2021-01-14 15:45:03.755000'),
#   'updated': Timestamp('2025-12-22 18:48:23.718000'),
#   'latitude': -44.6457,
#   'longitude': -80.1411,
#   'depth_km': 10,
#   'mag': 4.7,
#   'magType': 'mb',
#   'place': 'Off the coast of Aisen, Chile',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 340,
#   'net': 'us',
#   'code': '7000d028',
#   'ids': ',iscgem619717486,us7000d028,',
#   'sources': ',iscgem,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 4.925,
#   'rms': 1.17,
#   'gap': 159,
#   'type': 'earthquake'},
#  {'id': 'us7000d024',
#   'time': Timestamp('2021-01-14 15:03:39.015000'),
#   'updated': Timestamp('2021-03-20 21:25:41.040000'),
#   'latitude': -23.9696,
#   'longitude': 179.2301,
#   'depth_km': 550.65,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': 'south of the Fiji Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '7000d024',
#   'ids': ',us7000d024,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 6.29,
#   'rms': 0.87,
#   'gap': 122,
#   'type': 'earthquake'},
#  {'id': 'us7000d2e5',
#   'time': Timestamp('2021-01-14 14:45:11.461000'),
#   'updated': Timestamp('2021-03-20 21:25:40.040000'),
#   'latitude': 10.6076,
#   'longitude': -62.7629,
#   'depth_km': 110.14,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': '50 km W of Güiria, Venezuela',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '7000d2e5',
#   'ids': ',us7000d2e5,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 4.39,
#   'rms': 0.9,
#   'gap': 130,
#   'type': 'earthquake'},
#  {'id': 'us7000d2e9',
#   'time': Timestamp('2021-01-14 12:39:38.013000'),
#   'updated': Timestamp('2021-03-20 21:25:40.040000'),
#   'latitude': -15.4437,
#   'longitude': 166.9498,
#   'depth_km': 48.35,
#   'mag': 4.6,
#   'magType': 'mb',
#   'place': '24 km WNW of Luganville, Vanuatu',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 326,
#   'net': 'us',
#   'code': '7000d2e9',
#   'ids': ',us7000d2e9,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.244,
#   'rms': 1.02,
#   'gap': 79,
#   'type': 'earthquake'},
#  {'id': 'us6000d88r',
#   'time': Timestamp('2021-01-14 11:17:04.279000'),
#   'updated': Timestamp('2021-03-20 21:25:39.040000'),
#   'latitude': 33.1696,
#   'longitude': 138.4598,
#   'depth_km': 283.7,
#   'mag': 4.1,
#   'magType': 'mb',
#   'place': '160 km S of ?yama, Japan',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 259,
#   'net': 'us',
#   'code': '6000d88r',
#   'ids': ',us6000d88r,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 1.111,
#   'rms': 0.86,
#   'gap': 59,
#   'type': 'earthquake'},
#  {'id': 'us6000d88m',
#   'time': Timestamp('2021-01-14 10:49:20.879000'),
#   'updated': Timestamp('2022-08-09 02:26:43.132000'),
#   'latitude': 38.4545,
#   'longitude': 22.0128,
#   'depth_km': 10,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': '17 km N of Kamárai, Greece',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': 1,
#   'cdi': 4.8,
#   'mmi': None,
#   'sig': 272,
#   'net': 'us',
#   'code': '6000d88m',
#   'ids': ',us6000d88m,',
#   'sources': ',us,',
#   'types': ',dyfi,origin,phase-data,',
#   'nst': None,
#   'dmin': 0.619,
#   'rms': 1.28,
#   'gap': 44,
#   'type': 'earthquake'},
#  {'id': 'us7000d2dx',
#   'time': Timestamp('2021-01-14 09:54:26.560000'),
#   'updated': Timestamp('2021-03-20 21:25:38.040000'),
#   'latitude': 54.4805,
#   'longitude': -159.5428,
#   'depth_km': 22.04,
#   'mag': 3.3,
#   'magType': 'ml',
#   'place': '113 km SSE of Sand Point, Alaska',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 168,
#   'net': 'us',
#   'code': '7000d2dx',
#   'ids': ',ak021nb7e4y,us7000d2dx,',
#   'sources': ',ak,us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.352,
#   'rms': 0.56,
#   'gap': 165,
#   'type': 'earthquake'},
#  {'id': 'us7000d2e6',
#   'time': Timestamp('2021-01-14 09:22:00.700000'),
#   'updated': Timestamp('2021-03-20 21:25:38.040000'),
#   'latitude': 36.0905,
#   'longitude': 104.0101,
#   'depth_km': 10,
#   'mag': 4.5,
#   'magType': 'mb',
#   'place': '15 km ENE of Lanzhou, China',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 312,
#   'net': 'us',
#   'code': '7000d2e6',
#   'ids': ',us7000d2e6,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 7.397,
#   'rms': 0.6,
#   'gap': 149,
#   'type': 'earthquake'},
#  {'id': 'pr2021014009',
#   'time': Timestamp('2021-01-14 09:17:06.630000'),
#   'updated': Timestamp('2021-03-20 21:25:37.040000'),
#   'latitude': 19.2366,
#   'longitude': -65.0583,
#   'depth_km': 34,
#   'mag': 3.4,
#   'magType': 'md',
#   'place': '99 km N of Charlotte Amalie, U.S. Virgin Islands',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 178,
#   'net': 'pr',
#   'code': '2021014009',
#   'ids': ',us6000d88s,pr2021014009,',
#   'sources': ',us,pr,',
#   'types': ',origin,phase-data,',
#   'nst': 10,
#   'dmin': 1.2419,
#   'rms': 0.4,
#   'gap': 324,
#   'type': 'earthquake'},
#  {'id': 'us6000d88f',
#   'time': Timestamp('2021-01-14 09:09:30.926000'),
#   'updated': Timestamp('2021-03-20 21:25:37.040000'),
#   'latitude': 54.6664,
#   'longitude': 161.0428,
#   'depth_km': 68.18,
#   'mag': 4.2,
#   'magType': 'mb',
#   'place': '137 km SE of Atlasovo, Russia',
#   'status': 'reviewed',
#   'tsunami': 0,
#   'alert': None,
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'sig': 271,
#   'net': 'us',
#   'code': '6000d88f',
#   'ids': ',us6000d88f,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.172,
#   'rms': 0.89,
#   'gap': 81,
#   'type': 'earthquake'},
#  ...]

# %%
df=pd.DataFrame(all_records)

# %%
df.shape
# Out:
# (119253, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119253 entries, 0 to 119252
# Data columns (total 26 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         119253 non-null  object
#  1   time       119253 non-null  datetime64[ns]
#  2   updated    119253 non-null  datetime64[ns]
#  3   latitude   119253 non-null  float64
#  4   longitude  119253 non-null  float64
#  5   depth_km   119253 non-null  float64
#  6   mag        119253 non-null  float64
#  7   magType    119253 non-null  object
#  8   place      119253 non-null  object
#  9   status     119253 non-null  object
#  10  tsunami    119253 non-null  int64
#  11  alert      4875 non-null    object
#  12  felt       18140 non-null   float64
#  13  cdi        18140 non-null   float64
#  14  mmi        10550 non-null   float64
#  15  sig        119253 non-null  int64
#  16  net        119253 non-null  object
#  17  code       119253 non-null  object
#  18  ids        119253 non-null  object
#  19  sources    119253 non-null  object
#  20  types      119253 non-null  object
#  21  nst        91491 non-null   float64
#  22  dmin       115275 non-null  float64
#  23  rms        119234 non-null  float64
#  24  gap        116229 non-null  float64
#  25  type       119253 non-null  object
# dtypes: datetime64[ns](2), float64(11), int64(2), object(11)
# memory usage: 23.7+ MB

# %%
df.to_csv("project_raw",index= False)

# %%
from google.colab import files
files.download("project_raw.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1579/2893400561.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download("project_raw.csv")
#
# /usr/local/lib/python3.13/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: project_raw.csv

# %%
df.columns

# %%
df.head()
